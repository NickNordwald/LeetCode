# %% [markdown]
# ## Longest Substring Without Repeating Characters - Difficulty Medium
#
# Given a string `s`, find the length of the longest without duplicate characters.

# %%
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        last = {}
        left = 0
        best = 0

        for right, ch in enumerate(s):
            if ch in last and last[ch] >= left:
                left = last[ch] + 1
            last[ch] = right
            best = max(best, right - left + 1)

        return best

# %%
example = 'abcabcbb'
test = Solution()

test.lengthOfLongestSubstring(example)
# Out:
# 3

# %% [markdown]
# #### Comments
# - complexity O(n)
# - first had suboptimal solution which didn't slide properly to adjust the left end of the window
